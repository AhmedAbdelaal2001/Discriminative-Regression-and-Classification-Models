# %%
from utility import load_dataset, plot, save_parameters
from model import PoissonRegression

# %%
X_train, y_train = load_dataset("training_set.csv", addIntercept = True)
X_valid, y_valid = load_dataset("dev_set.csv")

# %%
poissonReg = PoissonRegression(alpha = 1e-2)
poissonReg.fit(X_train, y_train)
# Out:
# [0.08764    0.026296   0.061344   0.15201473 0.09816012]
# [0.16921923 0.05096813 0.1182511  0.2931054  0.18989911]
# [0.24144871 0.07318279 0.16826592 0.41648611 0.27146892]
# [0.3004985  0.0919902  0.2085083  0.51388868 0.3383615 ]
# [0.34367936 0.10674649 0.23693287 0.5790892  0.38721787]
# [0.371761   0.11767379 0.2540872  0.61311174 0.41861451]
# [0.38908961 0.125868   0.26322161 0.62484196 0.43737688]
# [0.40060938 0.1325592  0.26805018 0.6247097  0.44917237]
# [0.40952731 0.13854291 0.2709844  0.61953864 0.45772505]
# [0.41735544 0.1441946  0.27316083 0.61254728 0.46480641]
# [0.42470281 0.14966616 0.27503665 0.60502479 0.4711382 ]
# [0.43179982 0.15501555 0.27678427 0.59745128 0.47699981]
# [0.43873239 0.16026482 0.27846756 0.58999871 0.48250118]
# [0.44553322 0.16542281 0.28011042 0.58272581 0.48768947]
# [0.45221564 0.17049348 0.28172216 0.57565018 0.49258873]
# [0.45878589 0.17547908 0.28330681 0.56877462 0.49721437]
# ...

# %%
plot(X_valid, y_valid, poissonReg)

# %%
save_parameters(poissonReg)
# Out:
# [0.94806114 0.50514725 0.44291389 0.28183786 0.39992485]
# Parameters Saved.
